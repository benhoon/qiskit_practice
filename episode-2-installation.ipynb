# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.4.1'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService(channel="ibm_quantum_platform", #ibm_cloud
                                token = 'MY_API_TOKEN')
# Out:
# qiskit_runtime_service._discover_account:WARNING:2026-05-02 02:23:57,005: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-05-02 02:24:01,432: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().

# %%
QiskitRuntimeService.save_account(channel="ibm_quantum_platform",
                                  token = 'MY_API_TOKEN')
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 QiskitRuntimeService.save_account(channel="ibm_quantum_platform",
#       2                                   token = 'MY_API_TOKEN')
#
# File c:\Users\benle\miniconda3\envs\cwq\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:852, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     801 @staticmethod
#     802 def save_account(
#     803     token: str | None = None,
#    (...)    816     tags: list[str] | None = None,
#     817 ) -> None:
#     818     """Save the account to disk for future use.
#     819
#     820     Args:
#    (...)    849
#     850     """
# --> 852     AccountManager.save(
#     853         token=token,
#     854         url=url,
#     855         instance=instance,
#     856         channel=channel,
#     857         filename=filename,
#     858         name=name,
#     859         proxies=ProxyConfiguration(**proxies) if proxies else None,
#     860         verify=verify,
#     861         overwrite=overwrite,
#     862         set_as_default=set_as_default,
#     863         private_endpoint=private_endpoint,
#     864         region=region,
#     865         plans_preference=plans_preference,
#     866         tags=tags,
#     867     )
#
# File c:\Users\benle\miniconda3\envs\cwq\Lib\site-packages\qiskit_ibm_runtime\accounts\management.py:79, in AccountManager.save(cls, token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#      65 filename = os.path.expanduser(filename)
#      67 config = Account.create_account(
#      68     channel=channel,  # type: ignore[arg-type]
#      69     token=token,  # type: ignore[arg-type]
#    (...)     77     tags=tags,
#      78 )
# ---> 79 return save_config(
#      80     filename=filename,
#      81     name=name,
#      82     overwrite=overwrite,
#      83     config=config
#      84     # avoid storing invalid accounts
#      85     .validate().to_saved_format(),
#      86     set_as_default=set_as_default,
#      87 )
#
# File c:\Users\benle\miniconda3\envs\cwq\Lib\site-packages\qiskit_ibm_runtime\accounts\storage.py:34, in save_config(filename, name, config, overwrite, set_as_default)
#      31     data = json.load(json_in)
#      33 if data.get(name) and not overwrite:
# ---> 34     raise AccountAlreadyExistsError(
#      35         f"Named account ({name}) already exists. " f"Set overwrite=True to overwrite."
#      36     )
#      38 data[name] = config
#      40 # if set_as_default, but another account is defined as default, user must specify overwrite to change
#      41 # the default account.
#
# AccountAlreadyExistsError: 'Named account (default-ibm-quantum-platform) already exists. Set overwrite=True to overwrite.'

# %%
backend = service.backend(name = "ibm_kingston")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-05-02 02:25:51,063: Using instance: open-instance, plan: open

# %%
backend.num_qubits
# Out:
# 156
